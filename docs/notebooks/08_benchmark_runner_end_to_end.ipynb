# %% [markdown]
# # Benchmark Runner End-to-End

# %% [markdown]
# Run the benchmark runner and inspect outputs.

# %%
# Run from the repo root in a terminal
# python -m experiments.run_benchmarks --config configs/benchmark_suites/default.yaml --seed 0

# Outputs: results.csv, aggregate.csv, report.html, metadata.json
